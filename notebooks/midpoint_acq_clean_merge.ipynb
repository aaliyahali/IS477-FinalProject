# %% [markdown]
# # Data Acquisition, Cleaning, and Integration
# ### Project: Mapping and Modeling Drug-Related Deaths in Cook County
#
# This notebook demonstrates interim progress on data acquisition, cleaning, and integration. There is secondary notebook that will conduct EDA.
# It documents the steps taken so far to prepare datasets for spatial and demographic analysis, as outlined in our Project Plan.

# %%
# imports

import pandas as pd
import requests
import hashlib
import os

from pathlib import Path

from textblob import TextBlob

# %%
# Move working directory to project root
project_root = Path(".").resolve().parent 
os.chdir(project_root)

print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/aaliyahali/Desktop/is477/IS477-FinalProject

# %%
#!/usr/bin/env python3

import pandas as pd
import os
from pathlib import Path

# Ensure output directory exists
os.makedirs("data/processed", exist_ok=True)

# ---- Load cleaned ME data ----
me_path = Path("data/processed/me_cleaned.csv")
df_me = pd.read_csv(me_path, dtype={"Incident Zip Code": str})

# ---- Load ZIP → TRACT Crosswalk ----
crosswalk_path = Path("data/raw/ZIP_TRACT_062025.xlsx")
df_zip = pd.read_excel(crosswalk_path, dtype={"ZIP": str, "TRACT": str})

# ---- Load cleaned Census tract dataset ----
census_path = Path("data/processed/census_data_cleaned.csv")
df_census = pd.read_csv(census_path, dtype={"TRACT_FIPS": str})
# Out:
# /var/folders/m9/vbpb06vj43vdgzjt4xlxm9rm0000gn/T/ipykernel_61687/3646030261.py:12: DtypeWarning: Columns (25,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_me = pd.read_csv(me_path, dtype={"Incident Zip Code": str})

# %%
df_zip.columns
# Out:
# Index(['ZIP', 'TRACT', 'USPS_ZIP_PREF_CITY', 'USPS_ZIP_PREF_STATE',
#        'RES_RATIO', 'BUS_RATIO', 'OTH_RATIO', 'TOT_RATIO'],
#       dtype='object')

# %%
# ---- Filter Crosswalk to Cook County ----
df_zip_cook = df_zip[df_zip["TRACT"].str.startswith("17031")].copy()

# ---- Pick the primary tract per ZIP (highest residential share) ----
df_zip_primary = (
    df_zip_cook
    .sort_values(["ZIP", "RES_RATIO"], ascending=[True, False])
    .drop_duplicates(subset="ZIP")
    .reset_index(drop=True)
)

print("Original crosswalk row count:", len(df_zip))
print("Cook only:", len(df_zip_cook))
print("Primary ZIP→Tract:", len(df_zip_primary))
# Out:
# Original crosswalk row count: 189302
# Cook only: 2217
# Primary ZIP→Tract: 228

# %%
df_merge = df_me.merge(
    df_zip_primary,
    how="left",
    left_on="Incident Zip Code",
    right_on="ZIP"
)

print("Rows after ZIP→TRACT merge:", len(df_merge))
# should be ~51791 rows (not millions)
# Out:
# Rows after ZIP→TRACT merge: 51791

# %%
df_merge = df_merge.merge(
    df_census,
    how="left",
    left_on="TRACT",
    right_on="TRACT_FIPS"
)

print("Final row count:", len(df_merge))
# Out:
# Final row count: 51791

# %%
df_merge.columns
# Out:
# Index(['Case Number', 'Date of Incident', 'Date of Death', 'Age', 'Gender',
#        'Race', 'Latino', 'Manner of Death', 'Primary Cause',
#        'Primary Cause Line A', 'Primary Cause Line B', 'Primary Cause Line C',
#        'Secondary Cause', 'Gun Related', 'Opioid Related', 'Cold Related',
#        'Heat Related', 'Commissioner District', 'Incident Address',
#        'Incident City', 'Incident Zip Code', 'longitude', 'latitude',
#        'location', 'Residence City', 'Residence Zip', 'OBJECTID',
#        'Chicago Ward', 'Chicago Community Area', 'COVID Related',
#        'Updated_Date_of_Death', 'Year_of_Death', 'contanins_fentanyl',
#        'contains_cocaine', 'contains_heroin', 'ZIP', 'TRACT_x',
#        'USPS_ZIP_PREF_CITY', 'USPS_ZIP_PREF_STATE', 'RES_RATIO', 'BUS_RATIO',
#        'OTH_RATIO', 'TOT_RATIO', 'NAME', 'TotalPop', 'White_NonHisp', 'Black',
#        'Asian', 'Hispanic', 'MedianIncome', 'BelowPoverty',
#        'BachelorsOrHigher', 'Male_Under18', 'Female_Under18', 'Male_18_34',
#        'Female_18_34', 'Male_35_64', 'Female_35_64', 'Male_65plus',
#        'Female_65plus', 'LaborForce', 'Unemployed', 'NoHealthInsurance',
#        'MedianRent', 'STATE', 'COUNTY', 'TRACT_y', 'TRACT_FIPS', 'Age_Under18',
#        'Age_18_34', 'Age_35_64', 'Age_65plus', 'Pct_Black', 'Pct_Hispanic',
#        'Pct_Asian', 'Pct_WhiteNonHisp', 'Pct_BelowPoverty',
#        'Pct_BachelorsPlus', 'Pct_Unemployed', 'Pct_Uninsured'],
#       dtype='object')

# %%
# To display all columns
pd.set_option('display.max_columns', None)

# To display all rows
pd.set_option('display.max_rows', None)
df_merge.isna().mean()
# Out:
# Case Number               0.000000
# Date of Incident          0.024444
# Date of Death             0.000000
# Age                       0.003089
# Gender                    0.002047
# Race                      0.004171
# Latino                    0.000000
# Manner of Death           0.004653
# Primary Cause             0.000270
# Primary Cause Line A      0.000270
# Primary Cause Line B      0.644649
# Primary Cause Line C      0.948060
# Secondary Cause           0.567840
# Gun Related               0.004692
# Opioid Related            0.004692
# Cold Related              0.000000
# Heat Related              0.000000
# Commissioner District     0.109208
# Incident Address          0.002993
# Incident City             0.001506
# Incident Zip Code         0.000000
# longitude                 0.109112
# latitude                  0.109112
# location                  0.109112
# Residence City            0.020505
# Residence Zip             0.020293
# OBJECTID                  0.000000
# Chicago Ward              0.440926
# Chicago Community Area    0.440926
# COVID Related             0.000039
# Updated_Date_of_Death     0.000000
# Year_of_Death             0.000000
# contanins_fentanyl        0.000000
# contains_cocaine          0.000000
# contains_heroin           0.000000
# ZIP                       0.027244
# TRACT_x                   0.027244
# USPS_ZIP_PREF_CITY        0.027244
# USPS_ZIP_PREF_STATE       0.027244
# RES_RATIO                 0.027244
# BUS_RATIO                 0.027244
# OTH_RATIO                 0.027244
# TOT_RATIO                 0.027244
# NAME                      0.027244
# TotalPop                  0.027244
# White_NonHisp             0.027244
# Black                     0.027244
# Asian                     0.027244
# Hispanic                  0.027244
# MedianIncome              0.027244
# BelowPoverty              0.027244
# BachelorsOrHigher         0.027244
# Male_Under18              0.027244
# Female_Under18            0.027244
# Male_18_34                0.027244
# Female_18_34              0.027244
# Male_35_64                0.027244
# Female_35_64              0.027244
# Male_65plus               0.027244
# Female_65plus             0.027244
# LaborForce                0.027244
# Unemployed                0.027244
# NoHealthInsurance         0.027244
# MedianRent                0.027244
# STATE                     0.027244
# COUNTY                    0.027244
# TRACT_y                   0.027244
# TRACT_FIPS                0.027244
# Age_Under18               0.027244
# Age_18_34                 0.027244
# Age_35_64                 0.027244
# Age_65plus                0.027244
# Pct_Black                 0.028789
# Pct_Hispanic              0.028789
# Pct_Asian                 0.028789
# Pct_WhiteNonHisp          0.028789
# Pct_BelowPoverty          0.028789
# Pct_BachelorsPlus         0.028789
# Pct_Unemployed            0.028789
# Pct_Uninsured             0.028789
# dtype: float64

# %%
# To display all columns
pd.set_option('display.max_columns', None)

# To display all rows
pd.set_option('display.max_rows', None)

df_merge.isna().sum()
# Out:
# Case Number                   0
# Date of Incident           1266
# Date of Death                 0
# Age                         160
# Gender                      106
# Race                        216
# Latino                        0
# Manner of Death             241
# Primary Cause                14
# Primary Cause Line A         14
# Primary Cause Line B      33387
# Primary Cause Line C      49101
# Secondary Cause           29409
# Gun Related                 243
# Opioid Related              243
# Cold Related                  0
# Heat Related                  0
# Commissioner District      5656
# Incident Address            155
# Incident City                78
# Incident Zip Code             0
# longitude                  5651
# latitude                   5651
# location                   5651
# Residence City             1062
# Residence Zip              1051
# OBJECTID                      0
# Chicago Ward              22836
# Chicago Community Area    22836
# COVID Related                 2
# Updated_Date_of_Death         0
# Year_of_Death                 0
# contanins_fentanyl            0
# contains_cocaine              0
# contains_heroin               0
# ZIP                        1411
# TRACT_x                    1411
# USPS_ZIP_PREF_CITY         1411
# USPS_ZIP_PREF_STATE        1411
# RES_RATIO                  1411
# BUS_RATIO                  1411
# OTH_RATIO                  1411
# TOT_RATIO                  1411
# NAME                       1411
# TotalPop                   1411
# White_NonHisp              1411
# Black                      1411
# Asian                      1411
# Hispanic                   1411
# MedianIncome               1411
# BelowPoverty               1411
# BachelorsOrHigher          1411
# Male_Under18               1411
# Female_Under18             1411
# Male_18_34                 1411
# Female_18_34               1411
# Male_35_64                 1411
# Female_35_64               1411
# Male_65plus                1411
# Female_65plus              1411
# LaborForce                 1411
# Unemployed                 1411
# NoHealthInsurance          1411
# MedianRent                 1411
# STATE                      1411
# COUNTY                     1411
# TRACT_y                    1411
# TRACT_FIPS                 1411
# Age_Under18                1411
# Age_18_34                  1411
# Age_35_64                  1411
# Age_65plus                 1411
# Pct_Black                  1491
# Pct_Hispanic               1491
# Pct_Asian                  1491
# Pct_WhiteNonHisp           1491
# Pct_BelowPoverty           1491
# Pct_BachelorsPlus          1491
# Pct_Unemployed             1491
# Pct_Uninsured              1491
# dtype: int64

# %%
# Standardize tract column name
df_merge["TRACT"] = df_merge["TRACT_x"]

# Drop duplicate/unneeded columns
df_merge = df_merge.drop(columns=[
    "TRACT_x", "TRACT_y", "TRACT_FIPS",
    "USPS_ZIP_PREF_CITY", "USPS_ZIP_PREF_STATE",
    "BUS_RATIO", "OTH_RATIO", "TOT_RATIO"
], errors="ignore")

df_merge.head()
# Out:
#     Case Number        Date of Incident           Date of Death   Age  Gender  \
# 0  ME2025-02283  04/21/2023 02:08:00 PM  07/25/2023 12:00:00 AM  42.0    Male
# 1  ME2025-01581  03/10/2025 12:00:00 AM  05/03/2023 11:36:00 PM  84.0    Male
# 2  ME2025-01577  03/06/2022 08:11:00 PM  03/06/2022 07:20:00 PM  71.0    Male
# 3  ME2024-00980  11/30/2023 02:23:00 PM  12/01/2023 07:52:00 AM  87.0  Female
# 4  ME2024-00837  12/19/2023 02:42:00 PM  12/27/2023 11:03:00 PM  84.0    Male
#
#     Race  Latino Manner of Death  \
# 0  Black   False        ACCIDENT
# 1  Black   False         NATURAL
# 2  White    True         NATURAL
# 3  Asian   False         NATURAL
# 4  Black   False        ACCIDENT
#
#                                        Primary Cause  \
# 0                          COMPLICATIONS OF DROWNING
# 1          MALIGNANT NEOPLASM OF THE URINARY BLADDER
# 2                                 CHRONIC ETHANOLISM
# 3                           SEPSIS. BRONCHOPNEUMONIA
# 4  THERMAL AND INHALATION INJURIES. RESIDENTIAL F...
#
#                         Primary Cause Line A Primary Cause Line B  \
# 0                  COMPLICATIONS OF DROWNING                  NaN
# 1  MALIGNANT NEOPLASM OF THE URINARY BLADDER                  NaN
# 2                         CHRONIC ETHANOLISM                  NaN
# 3                                     SEPSIS     BRONCHOPNEUMONIA
# 4            THERMAL AND INHALATION INJURIES     RESIDENTIAL FIRE
#
#          Primary Cause Line C  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4  MISUSE OF SMOKING MATERIAL
#
#                                      Secondary Cause Gun Related  \
# 0  HYPERTENSIVE CARDIOVASCULAR DISEASE, CHRONIC S...       False
# 1                                                NaN       False
# 2                                  DIABETES MELLITUS       False
# 3  HYPERTENSIVE AND ATHEROSCLEROTIC CARDIOVASCULA...       False
# 4                                                NaN       False
#
#   Opioid Related  Cold Related  Heat Related  Commissioner District  \
# 0          False         False         False                    1.0
# 1          False         False         False                    5.0
# 2          False         False         False                    7.0
# 3          False         False         False                    NaN
# 4          False         False         False                   10.0
#
#              Incident Address    Incident City Incident Zip Code  longitude  \
# 0   100 N Central Park Avenue          CHICAGO             60624 -87.716075
# 1             230 E. 11th St.  CHICAGO HEIGHTS             60411 -87.625580
# 2         2551 W. CERMAK ROAD          CHICAGO             60608 -87.690001
# 3       8110 Lincoln Ave. #2C          CHICAGO             60646        NaN
# 4  4645 N Sheridan Rd Apt 407          CHICAGO             60640 -87.654168
#
#     latitude                  location Residence City Residence Zip  OBJECTID  \
# 0  41.882688  (41.882688, -87.7160745)   Elmwood Park       60707.0     89165
# 1  41.511357  (41.511357, -87.6255795)            NaN           NaN     88467
# 2  41.850558  (41.850558, -87.6900015)        Chicago       60623.0     88470
# 3        NaN                       NaN         Skokie       60077.0     80661
# 4  41.966649   (41.966649, -87.654168)        Chicago       60640.0     80512
#
#    Chicago Ward Chicago Community Area COVID Related Updated_Date_of_Death  \
# 0          28.0     EAST GARFIELD PARK         False   2023-07-25 00:00:00
# 1           NaN                    NaN         False   2023-05-03 23:36:00
# 2          28.0         SOUTH LAWNDALE         False   2022-03-06 19:20:00
# 3           NaN                    NaN         False   2023-12-01 07:52:00
# 4          46.0                 UPTOWN         False   2023-12-27 23:03:00
#
#    Year_of_Death  contanins_fentanyl  contains_cocaine  contains_heroin  \
# 0         2023.0               False             False            False
# 1         2023.0               False             False            False
# 2         2022.0               False             False            False
# 3         2023.0               False             False            False
# 4         2023.0               False             False            False
#
#      ZIP  RES_RATIO                                         NAME  TotalPop  \
# 0  60624   0.142876     Census Tract 2315; Cook County; Illinois    6183.0
# 1  60411   0.107736  Census Tract 8285.08; Cook County; Illinois    4077.0
# 2  60608   0.082878     Census Tract 3106; Cook County; Illinois    5136.0
# 3  60646   0.219736     Census Tract 1203; Cook County; Illinois    7093.0
# 4  60640   0.104682      Census Tract 313; Cook County; Illinois    6841.0
#
#    White_NonHisp   Black   Asian  Hispanic  MedianIncome  BelowPoverty  \
# 0          332.0  3361.0   176.0    2281.0       31755.0        1956.0
# 1          671.0  2396.0     0.0     744.0       29207.0        1159.0
# 2         1533.0   228.0   349.0    2900.0       75604.0         583.0
# 3         5562.0    21.0   602.0     598.0      137043.0         433.0
# 4         3756.0   773.0  1064.0     944.0       65617.0        1291.0
#
#    BachelorsOrHigher  Male_Under18  Female_Under18  Male_18_34  Female_18_34  \
# 0              311.0         242.0           551.0        87.0         137.0
# 1              343.0         291.0           180.0        44.0           0.0
# 2             1012.0          40.0           131.0         0.0           0.0
# 3             1783.0         329.0           249.0        40.0          19.0
# 4             1738.0         154.0            57.0         0.0           0.0
#
#    Male_35_64  Female_35_64  Male_65plus  Female_65plus  LaborForce  \
# 0         0.0         139.0         25.0           39.0      2437.0
# 1        42.0         319.0        114.0           55.0      1798.0
# 2        76.0         207.0         45.0            0.0      3040.0
# 3       136.0          55.0        171.0           48.0      3446.0
# 4        26.0          36.0        145.0           54.0      3931.0
#
#    Unemployed  NoHealthInsurance  MedianRent  STATE  COUNTY  Age_Under18  \
# 0       394.0               45.0      1133.0   17.0    31.0        793.0
# 1        85.0              153.0      1075.0   17.0    31.0        471.0
# 2       143.0                0.0      1333.0   17.0    31.0        171.0
# 3        93.0               82.0      1368.0   17.0    31.0        578.0
# 4       184.0               93.0      1239.0   17.0    31.0        211.0
#
#    Age_18_34  Age_35_64  Age_65plus  Pct_Black  Pct_Hispanic  Pct_Asian  \
# 0      224.0      139.0        64.0  54.358726     36.891477   2.846515
# 1       44.0      361.0       169.0  58.768702     18.248712   0.000000
# 2        0.0      283.0        45.0   4.439252     56.464174   6.795171
# 3       59.0      191.0       219.0   0.296067      8.430847   8.487241
# 4        0.0       62.0       199.0  11.299518     13.799152  15.553282
#
#    Pct_WhiteNonHisp  Pct_BelowPoverty  Pct_BachelorsPlus  Pct_Unemployed  \
# 0          5.369562         31.635129           5.029921       16.167419
# 1         16.458180         28.427766           8.413049        4.727475
# 2         29.848131         11.351246          19.704050        4.703947
# 3         78.415339          6.104610          25.137459        2.698781
# 4         54.904254         18.871510          25.405642        4.680743
#
#    Pct_Uninsured        TRACT
# 0       0.727802  17031231500
# 1       3.752759  17031828508
# 2       0.000000  17031310600
# 3       1.156069  17031120300
# 4       1.359450  17031031300

# %%
# scripts/acquire_data.py

df_me = pd.read_csv("data/raw/Medical_Examiner_Case_Archive_20251104.csv", low_memory=False)

# %%
os.makedirs("data/raw", exist_ok=True)

# ACS 5-Year 2023 (data collected 2019–2023)
url = "https://api.census.gov/data/2023/acs/acs5"

variables = [
    # Population + race
    "B01003_001E",  # total population
    "B03002_003E",  # white (non-Hispanic)
    "B03002_004E",  # black
    "B03002_006E",  # asian
    "B03002_012E",  # hispanic

    # Income & poverty
    "B19013_001E",  # median income
    "B17001_002E",  # below poverty

    # Education
    "B15003_022E",  # bachelor's degree or higher

    # Age structure (male + female counts)
    "B01001_003E", "B01001_027E",  # under 18
    "B01001_007E", "B01001_031E",  # 18–34
    "B01001_010E", "B01001_034E",  # 35–64
    "B01001_020E", "B01001_044E",  # 65+

    # New: Unemployment, Health Insurance, Rent
    "B23025_002E",  # labor force
    "B23025_005E",  # unemployed
    "B27010_017E",  # no health insurance (all people)
    "B25064_001E"   # median gross rent
]

params = {
    "get": ",".join(["NAME"] + variables),
    "for": "tract:*",
    "in": "county:031 state:17"  # Cook County, IL
}

r = requests.get(url, params=params)
r.raise_for_status()

data = r.json()
cols = data[0]
rows = data[1:]
df_census = pd.DataFrame(rows, columns=cols)

# Rename columns for clarity
df_census = df_census.rename(columns={
    "B01003_001E": "TotalPop",
    "B03002_003E": "White_NonHisp",
    "B03002_004E": "Black",
    "B03002_006E": "Asian",
    "B03002_012E": "Hispanic",
    "B19013_001E": "MedianIncome",
    "B17001_002E": "BelowPoverty",
    "B15003_022E": "BachelorsOrHigher",
    "B01001_003E": "Male_Under18",
    "B01001_027E": "Female_Under18",
    "B01001_007E": "Male_18_34",
    "B01001_031E": "Female_18_34",
    "B01001_010E": "Male_35_64",
    "B01001_034E": "Female_35_64",
    "B01001_020E": "Male_65plus",
    "B01001_044E": "Female_65plus",
    "B23025_002E": "LaborForce",
    "B23025_005E": "Unemployed",
    "B27010_017E": "NoHealthInsurance",
    "B25064_001E": "MedianRent",
    "state": "STATE",
    "county": "COUNTY",
    "tract": "TRACT"
})

# Unique tract ID for merging
df_census["TRACT_FIPS"] = df_census["STATE"] + df_census["COUNTY"] + df_census["TRACT"].str.zfill(6)

df_census.to_csv("data/raw/census_tract_data.csv", index=False)
print(f"Saved enriched Census data for {len(df_census)} tracts.")
# Out:
# Saved enriched Census data for 1332 tracts.

# %%
df_census.head()
# Out:
#                                          NAME TotalPop White_NonHisp Black  \
# 0     Census Tract 101; Cook County; Illinois     3726          1297  1376
# 1  Census Tract 102.01; Cook County; Illinois     7588          1406  2301
# 2  Census Tract 102.02; Cook County; Illinois     2609           967   949
# 3     Census Tract 103; Cook County; Illinois     6311          3094  1298
# 4     Census Tract 104; Cook County; Illinois     4282          3173   296
#
#   Asian Hispanic MedianIncome BelowPoverty BachelorsOrHigher Male_Under18  \
# 0   137      809        69460          508               775           88
# 1   376     2622        49639         1892               684          455
# 2   212      423        55119          524               656            9
# 3   342     1426        65871          431              1585          148
# 4   324      340        49017          463               999           25
#
#   Female_Under18 Male_18_34 Female_18_34 Male_35_64 Female_35_64 Male_65plus  \
# 0             41         52          141        128           46         108
# 1            353         43           62        161          317         143
# 2             32         48            0         43           90          24
# 3             25         33           35         53          179          26
# 4             43        358          688         91          100          83
#
#   Female_65plus LaborForce Unemployed NoHealthInsurance MedianRent STATE  \
# 0            56       2579        260               130       1252    17
# 1           119       4007        317                40       1333    17
# 2            31       1449        135                36       1292    17
# 3            84       3923        166                 0       1257    17
# 4            18       2282         78                16       1248    17
#
#   COUNTY   TRACT   TRACT_FIPS
# 0    031  010100  17031010100
# 1    031  010201  17031010201
# 2    031  010202  17031010202
# 3    031  010300  17031010300
# 4    031  010400  17031010400

# %%
df_me.head()
# Out:
#     Case Number        Date of Incident           Date of Death   Age  Gender  \
# 0  ME2025-05835  11/04/2025 02:09:00 PM  11/04/2025 01:57:00 PM  57.0    Male
# 1  ME2025-05834  09/24/2025 01:48:00 PM  11/04/2025 12:20:00 PM  55.0  Female
# 2  ME2025-05833  11/04/2025 12:00:00 AM  11/04/2025 12:40:00 PM  69.0  Female
# 3  ME2025-05832  11/04/2025 01:12:00 PM  11/04/2025 12:40:00 PM  75.0    Male
# 4  ME2025-05831  11/04/2025 01:41:00 PM  11/04/2025 09:48:00 AM  30.0    Male
#
#     Race  Latino Manner of Death Primary Cause Primary Cause Line A  \
# 0  Black   False             NaN           NaN                  NaN
# 1  White    True             NaN           NaN                  NaN
# 2  White    True             NaN           NaN                  NaN
# 3  White   False             NaN           NaN                  NaN
# 4  Black   False             NaN           NaN                  NaN
#
#   Primary Cause Line B Primary Cause Line C Secondary Cause Gun Related  \
# 0                  NaN                  NaN             NaN         NaN
# 1                  NaN                  NaN             NaN         NaN
# 2                  NaN                  NaN             NaN         NaN
# 3                  NaN                  NaN             NaN         NaN
# 4                  NaN                  NaN             NaN         NaN
#
#   Opioid Related  Cold Related  Heat Related  Commissioner District  \
# 0            NaN         False         False                    2.0
# 1            NaN         False         False                    7.0
# 2            NaN         False         False                    1.0
# 3            NaN         False         False                    1.0
# 4            NaN         False         False                    5.0
#
#                   Incident Address Incident City Incident Zip Code  longitude  \
# 0      901 WEST 63RD ST., UNIT 324       CHICAGO             60621 -87.647293
# 1  4803 S LAFLIN ST FLOOR ONE UNIT       CHICAGO             60609 -87.662232
# 2     2737 W HIRSCH STREET 2ND FLR       CHICAGO             60622 -87.696022
# 3     2737 W HIRSCH STREET 2ND FLR       CHICAGO             60622 -87.696022
# 4                    1722 W. 170TH   HAZEL CREST             60429 -87.659707
#
#     latitude                     location Residence City Residence Zip  \
# 0  41.779635  (41.77963481, -87.64729284)        Chicago         60621
# 1  41.806638      (41.806638, -87.662232)        Chicago         60609
# 2  41.906421     (41.906421, -87.6960225)        Chicago         60612
# 3  41.906421     (41.906421, -87.6960225)        Chicago         60622
# 4  41.581080      (41.58108, -87.6597075)    Hazel Crest         60429
#
#    OBJECTID  Chicago Ward Chicago Community Area COVID Related
# 0     92724          16.0              ENGLEWOOD         False
# 1     92725          20.0               NEW CITY         False
# 2     92720          26.0              WEST TOWN         False
# 3     92719          26.0              WEST TOWN         False
# 4     92722           NaN                    NaN         False

# %% [markdown]
# ### Exploratory Data Analysis

# %%
len(df_me)
# Out:
# 92642

# %%
df_me.dtypes
# Out:
# Case Number                object
# Date of Incident           object
# Date of Death              object
# Age                       float64
# Gender                     object
# Race                       object
# Latino                       bool
# Manner of Death            object
# Primary Cause              object
# Primary Cause Line A       object
# Primary Cause Line B       object
# Primary Cause Line C       object
# Secondary Cause            object
# Gun Related                object
# Opioid Related             object
# Cold Related                 bool
# Heat Related                 bool
# Commissioner District     float64
# Incident Address           object
# Incident City              object
# Incident Zip Code          object
# longitude                 float64
# latitude                  float64
# location                   object
# Residence City             object
# Residence Zip              object
# OBJECTID                    int64
# Chicago Ward              float64
# Chicago Community Area     object
# COVID Related              object
# dtype: object

# %%
df_me.columns
# Out:
# Index(['Case Number', 'Date of Incident', 'Date of Death', 'Age', 'Gender',
#        'Race', 'Latino', 'Manner of Death', 'Primary Cause',
#        'Primary Cause Line A', 'Primary Cause Line B', 'Primary Cause Line C',
#        'Secondary Cause', 'Gun Related', 'Opioid Related', 'Cold Related',
#        'Heat Related', 'Commissioner District', 'Incident Address',
#        'Incident City', 'Incident Zip Code', 'longitude', 'latitude',
#        'location', 'Residence City', 'Residence Zip', 'OBJECTID',
#        'Chicago Ward', 'Chicago Community Area', 'COVID Related'],
#       dtype='object')

# %% [markdown]
# ## Cleaning + Pre-Processing

# %% [markdown]
# ### Census Data

# %%
df_census.isna().sum()
# no missing values
# Out:
# NAME                 0
# TotalPop             0
# White_NonHisp        0
# Black                0
# Asian                0
# Hispanic             0
# MedianIncome         0
# BelowPoverty         0
# BachelorsOrHigher    0
# Male_Under18         0
# Female_Under18       0
# Male_18_34           0
# Female_18_34         0
# Male_35_64           0
# Female_35_64         0
# Male_65plus          0
# Female_65plus        0
# LaborForce           0
# Unemployed           0
# NoHealthInsurance    0
# MedianRent           0
# STATE                0
# COUNTY               0
# TRACT                0
# TRACT_FIPS           0
# dtype: int64

# %%
df_census.head()
# Out:
#                                          NAME TotalPop White_NonHisp Black  \
# 0     Census Tract 101; Cook County; Illinois     3726          1297  1376
# 1  Census Tract 102.01; Cook County; Illinois     7588          1406  2301
# 2  Census Tract 102.02; Cook County; Illinois     2609           967   949
# 3     Census Tract 103; Cook County; Illinois     6311          3094  1298
# 4     Census Tract 104; Cook County; Illinois     4282          3173   296
#
#   Asian Hispanic MedianIncome BelowPoverty BachelorsOrHigher Male_Under18  \
# 0   137      809        69460          508               775           88
# 1   376     2622        49639         1892               684          455
# 2   212      423        55119          524               656            9
# 3   342     1426        65871          431              1585          148
# 4   324      340        49017          463               999           25
#
#   Female_Under18 Male_18_34 Female_18_34 Male_35_64 Female_35_64 Male_65plus  \
# 0             41         52          141        128           46         108
# 1            353         43           62        161          317         143
# 2             32         48            0         43           90          24
# 3             25         33           35         53          179          26
# 4             43        358          688         91          100          83
#
#   Female_65plus LaborForce Unemployed NoHealthInsurance MedianRent STATE  \
# 0            56       2579        260               130       1252    17
# 1           119       4007        317                40       1333    17
# 2            31       1449        135                36       1292    17
# 3            84       3923        166                 0       1257    17
# 4            18       2282         78                16       1248    17
#
#   COUNTY   TRACT   TRACT_FIPS
# 0    031  010100  17031010100
# 1    031  010201  17031010201
# 2    031  010202  17031010202
# 3    031  010300  17031010300
# 4    031  010400  17031010400

# %%
df_census.dtypes
# Out:
# NAME                 object
# TotalPop             object
# White_NonHisp        object
# Black                object
# Asian                object
# Hispanic             object
# MedianIncome         object
# BelowPoverty         object
# BachelorsOrHigher    object
# Male_Under18         object
# Female_Under18       object
# Male_18_34           object
# Female_18_34         object
# Male_35_64           object
# Female_35_64         object
# Male_65plus          object
# Female_65plus        object
# LaborForce           object
# Unemployed           object
# NoHealthInsurance    object
# MedianRent           object
# STATE                object
# COUNTY               object
# TRACT                object
# TRACT_FIPS           object
# dtype: object

# %%
# convert string columns to numeric values for computational purposes
num_cols = [c for c in df_census.columns if c not in ["NAME", "STATE", "COUNTY", "TRACT", "TRACT_FIPS"]] 
df_census[num_cols] = df_census[num_cols].apply(pd.to_numeric, errors="coerce")

# %%
df_census.dtypes
# Out:
# NAME                 object
# TotalPop              int64
# White_NonHisp         int64
# Black                 int64
# Asian                 int64
# Hispanic              int64
# MedianIncome          int64
# BelowPoverty          int64
# BachelorsOrHigher     int64
# Male_Under18          int64
# Female_Under18        int64
# Male_18_34            int64
# Female_18_34          int64
# Male_35_64            int64
# Female_35_64          int64
# Male_65plus           int64
# Female_65plus         int64
# LaborForce            int64
# Unemployed            int64
# NoHealthInsurance     int64
# MedianRent            int64
# STATE                object
# COUNTY               object
# TRACT                object
# TRACT_FIPS           object
# dtype: object

# %%
# age group totals for analysis 
df_census["Age_Under18"] = df_census["Male_Under18"] + df_census["Female_Under18"]
df_census["Age_18_34"] = df_census["Male_18_34"] + df_census["Female_18_34"]
df_census["Age_35_64"] = df_census["Male_35_64"] + df_census["Female_35_64"]
df_census["Age_65plus"] = df_census["Male_65plus"] + df_census["Female_65plus"]

# %%
# demographic porportions 
df_census["Pct_Black"] = df_census["Black"] / df_census["TotalPop"] * 100
df_census["Pct_Hispanic"] = df_census["Hispanic"] / df_census["TotalPop"] * 100
df_census["Pct_Asian"] = df_census["Asian"] / df_census["TotalPop"] * 100
df_census["Pct_WhiteNonHisp"] = df_census["White_NonHisp"] / df_census["TotalPop"] * 100

# %%
# education proportions
df_census["Pct_BelowPoverty"] = df_census["BelowPoverty"] / df_census["TotalPop"] * 100
df_census["Pct_BachelorsPlus"] = df_census["BachelorsOrHigher"] / df_census["TotalPop"] * 100

#unemployment + insurance proportions
df_census["Pct_Unemployed"] = (df_census["Unemployed"] / df_census["LaborForce"]) * 100
df_census["Pct_Uninsured"] = (df_census["NoHealthInsurance"] / df_census["TotalPop"]) * 100

# %%
df_census.to_csv("data/processed/census_data_cleaned.csv", index=False)

# %% [markdown]
# ### ME Data

# %%
df_me.head()
# Out:
#     Case Number        Date of Incident           Date of Death   Age  Gender  \
# 0  ME2025-05835  11/04/2025 02:09:00 PM  11/04/2025 01:57:00 PM  57.0    Male
# 1  ME2025-05834  09/24/2025 01:48:00 PM  11/04/2025 12:20:00 PM  55.0  Female
# 2  ME2025-05833  11/04/2025 12:00:00 AM  11/04/2025 12:40:00 PM  69.0  Female
# 3  ME2025-05832  11/04/2025 01:12:00 PM  11/04/2025 12:40:00 PM  75.0    Male
# 4  ME2025-05831  11/04/2025 01:41:00 PM  11/04/2025 09:48:00 AM  30.0    Male
#
#     Race  Latino Manner of Death Primary Cause Primary Cause Line A  \
# 0  Black   False             NaN           NaN                  NaN
# 1  White    True             NaN           NaN                  NaN
# 2  White    True             NaN           NaN                  NaN
# 3  White   False             NaN           NaN                  NaN
# 4  Black   False             NaN           NaN                  NaN
#
#   Primary Cause Line B Primary Cause Line C Secondary Cause Gun Related  \
# 0                  NaN                  NaN             NaN         NaN
# 1                  NaN                  NaN             NaN         NaN
# 2                  NaN                  NaN             NaN         NaN
# 3                  NaN                  NaN             NaN         NaN
# 4                  NaN                  NaN             NaN         NaN
#
#   Opioid Related  Cold Related  Heat Related  Commissioner District  \
# 0            NaN         False         False                    2.0
# 1            NaN         False         False                    7.0
# 2            NaN         False         False                    1.0
# 3            NaN         False         False                    1.0
# 4            NaN         False         False                    5.0
#
#                   Incident Address Incident City Incident Zip Code  longitude  \
# 0      901 WEST 63RD ST., UNIT 324       CHICAGO             60621 -87.647293
# 1  4803 S LAFLIN ST FLOOR ONE UNIT       CHICAGO             60609 -87.662232
# 2     2737 W HIRSCH STREET 2ND FLR       CHICAGO             60622 -87.696022
# 3     2737 W HIRSCH STREET 2ND FLR       CHICAGO             60622 -87.696022
# 4                    1722 W. 170TH   HAZEL CREST             60429 -87.659707
#
#     latitude                     location Residence City Residence Zip  \
# 0  41.779635  (41.77963481, -87.64729284)        Chicago         60621
# 1  41.806638      (41.806638, -87.662232)        Chicago         60609
# 2  41.906421     (41.906421, -87.6960225)        Chicago         60612
# 3  41.906421     (41.906421, -87.6960225)        Chicago         60622
# 4  41.581080      (41.58108, -87.6597075)    Hazel Crest         60429
#
#    OBJECTID  Chicago Ward Chicago Community Area COVID Related
# 0     92724          16.0              ENGLEWOOD         False
# 1     92725          20.0               NEW CITY         False
# 2     92720          26.0              WEST TOWN         False
# 3     92719          26.0              WEST TOWN         False
# 4     92722           NaN                    NaN         False

# %%
df_me.dtypes
# Out:
# Case Number                object
# Date of Incident           object
# Date of Death              object
# Age                       float64
# Gender                     object
# Race                       object
# Latino                       bool
# Manner of Death            object
# Primary Cause              object
# Primary Cause Line A       object
# Primary Cause Line B       object
# Primary Cause Line C       object
# Secondary Cause            object
# Gun Related                object
# Opioid Related             object
# Cold Related                 bool
# Heat Related                 bool
# Commissioner District     float64
# Incident Address           object
# Incident City              object
# Incident Zip Code          object
# longitude                 float64
# latitude                  float64
# location                   object
# Residence City             object
# Residence Zip              object
# OBJECTID                    int64
# Chicago Ward              float64
# Chicago Community Area     object
# COVID Related              object
# dtype: object

# %%
## census data is from 2019-2023, so need to filter the ME data to match that

# %%
df_me["Updated_Date_of_Death"] = pd.to_datetime(df_me['Date of Death'], format='%m/%d/%Y %I:%M:%S %p')

# %%
df_me.columns
# Out:
# Index(['Case Number', 'Date of Incident', 'Date of Death', 'Age', 'Gender',
#        'Race', 'Latino', 'Manner of Death', 'Primary Cause',
#        'Primary Cause Line A', 'Primary Cause Line B', 'Primary Cause Line C',
#        'Secondary Cause', 'Gun Related', 'Opioid Related', 'Cold Related',
#        'Heat Related', 'Commissioner District', 'Incident Address',
#        'Incident City', 'Incident Zip Code', 'longitude', 'latitude',
#        'location', 'Residence City', 'Residence Zip', 'OBJECTID',
#        'Chicago Ward', 'Chicago Community Area', 'COVID Related',
#        'Updated_Date_of_Death'],
#       dtype='object')

# %%
df_me["Year_of_Death"] = df_me["Updated_Date_of_Death"].dt.year
df_me.head()
# Out:
#     Case Number        Date of Incident           Date of Death   Age  Gender  \
# 0  ME2025-05835  11/04/2025 02:09:00 PM  11/04/2025 01:57:00 PM  57.0    Male
# 1  ME2025-05834  09/24/2025 01:48:00 PM  11/04/2025 12:20:00 PM  55.0  Female
# 2  ME2025-05833  11/04/2025 12:00:00 AM  11/04/2025 12:40:00 PM  69.0  Female
# 3  ME2025-05832  11/04/2025 01:12:00 PM  11/04/2025 12:40:00 PM  75.0    Male
# 4  ME2025-05831  11/04/2025 01:41:00 PM  11/04/2025 09:48:00 AM  30.0    Male
#
#     Race  Latino Manner of Death Primary Cause Primary Cause Line A  \
# 0  Black   False             NaN           NaN                  NaN
# 1  White    True             NaN           NaN                  NaN
# 2  White    True             NaN           NaN                  NaN
# 3  White   False             NaN           NaN                  NaN
# 4  Black   False             NaN           NaN                  NaN
#
#   Primary Cause Line B Primary Cause Line C Secondary Cause Gun Related  \
# 0                  NaN                  NaN             NaN         NaN
# 1                  NaN                  NaN             NaN         NaN
# 2                  NaN                  NaN             NaN         NaN
# 3                  NaN                  NaN             NaN         NaN
# 4                  NaN                  NaN             NaN         NaN
#
#   Opioid Related  Cold Related  Heat Related  Commissioner District  \
# 0            NaN         False         False                    2.0
# 1            NaN         False         False                    7.0
# 2            NaN         False         False                    1.0
# 3            NaN         False         False                    1.0
# 4            NaN         False         False                    5.0
#
#                   Incident Address Incident City Incident Zip Code  longitude  \
# 0      901 WEST 63RD ST., UNIT 324       CHICAGO             60621 -87.647293
# 1  4803 S LAFLIN ST FLOOR ONE UNIT       CHICAGO             60609 -87.662232
# 2     2737 W HIRSCH STREET 2ND FLR       CHICAGO             60622 -87.696022
# 3     2737 W HIRSCH STREET 2ND FLR       CHICAGO             60622 -87.696022
# 4                    1722 W. 170TH   HAZEL CREST             60429 -87.659707
#
#     latitude                     location Residence City Residence Zip  \
# 0  41.779635  (41.77963481, -87.64729284)        Chicago         60621
# 1  41.806638      (41.806638, -87.662232)        Chicago         60609
# 2  41.906421     (41.906421, -87.6960225)        Chicago         60612
# 3  41.906421     (41.906421, -87.6960225)        Chicago         60622
# 4  41.581080      (41.58108, -87.6597075)    Hazel Crest         60429
#
#    OBJECTID  Chicago Ward Chicago Community Area COVID Related  \
# 0     92724          16.0              ENGLEWOOD         False
# 1     92725          20.0               NEW CITY         False
# 2     92720          26.0              WEST TOWN         False
# 3     92719          26.0              WEST TOWN         False
# 4     92722           NaN                    NaN         False
#
#   Updated_Date_of_Death  Year_of_Death
# 0   2025-11-04 13:57:00         2025.0
# 1   2025-11-04 12:20:00         2025.0
# 2   2025-11-04 12:40:00         2025.0
# 3   2025-11-04 12:40:00         2025.0
# 4   2025-11-04 09:48:00         2025.0

# %%
df_me = df_me[(df_me["Year_of_Death"] >= 2019) & (df_me["Year_of_Death"] <= 2023)]
df_me.head()
# Out:
#         Case Number        Date of Incident           Date of Death   Age  \
# 3552   ME2025-02283  04/21/2023 02:08:00 PM  07/25/2023 12:00:00 AM  42.0
# 4254   ME2025-01581  03/10/2025 12:00:00 AM  05/03/2023 11:36:00 PM  84.0
# 4257   ME2025-01578                     NaN  05/15/2023 06:29:00 AM  76.0
# 4258   ME2025-01577  03/06/2022 08:11:00 PM  03/06/2022 07:20:00 PM  71.0
# 12057  ME2024-00980  11/30/2023 02:23:00 PM  12/01/2023 07:52:00 AM  87.0
#
#        Gender   Race  Latino Manner of Death  \
# 3552     Male  Black   False        ACCIDENT
# 4254     Male  Black   False         NATURAL
# 4257     Male  White   False         NATURAL
# 4258     Male  White    True         NATURAL
# 12057  Female  Asian   False         NATURAL
#
#                                            Primary Cause  \
# 3552                           COMPLICATIONS OF DROWNING
# 4254           MALIGNANT NEOPLASM OF THE URINARY BLADDER
# 4257   HYPERTENSIVE ARTERIOSCLEROTIC CARDIOVASCULAR D...
# 4258                                  CHRONIC ETHANOLISM
# 12057                           SEPSIS. BRONCHOPNEUMONIA
#
#                                     Primary Cause Line A Primary Cause Line B  \
# 3552                           COMPLICATIONS OF DROWNING                  NaN
# 4254           MALIGNANT NEOPLASM OF THE URINARY BLADDER                  NaN
# 4257   HYPERTENSIVE ARTERIOSCLEROTIC CARDIOVASCULAR D...                  NaN
# 4258                                  CHRONIC ETHANOLISM                  NaN
# 12057                                             SEPSIS     BRONCHOPNEUMONIA
#
#       Primary Cause Line C                                    Secondary Cause  \
# 3552                   NaN  HYPERTENSIVE CARDIOVASCULAR DISEASE, CHRONIC S...
# 4254                   NaN                                                NaN
# 4257                   NaN                                  DIABETES MELLITUS
# 4258                   NaN                                  DIABETES MELLITUS
# 12057                  NaN  HYPERTENSIVE AND ATHEROSCLEROTIC CARDIOVASCULA...
#
#       Gun Related Opioid Related  Cold Related  Heat Related  \
# 3552        False          False         False         False
# 4254        False          False         False         False
# 4257        False          False         False         False
# 4258        False          False         False         False
# 12057       False          False         False         False
#
#        Commissioner District           Incident Address    Incident City  \
# 3552                     1.0  100 N Central Park Avenue          CHICAGO
# 4254                     5.0            230 E. 11th St.  CHICAGO HEIGHTS
# 4257                     NaN                        NaN          UNKNOWN
# 4258                     7.0        2551 W. CERMAK ROAD          CHICAGO
# 12057                    NaN      8110 Lincoln Ave. #2C          CHICAGO
#
#       Incident Zip Code  longitude   latitude                  location  \
# 3552              60624 -87.716075  41.882688  (41.882688, -87.7160745)
# 4254              60411 -87.625580  41.511357  (41.511357, -87.6255795)
# 4257                NaN        NaN        NaN                       NaN
# 4258              60608 -87.690001  41.850558  (41.850558, -87.6900015)
# 12057             60646        NaN        NaN                       NaN
#
#       Residence City Residence Zip  OBJECTID  Chicago Ward  \
# 3552    Elmwood Park         60707     89165          28.0
# 4254             NaN           NaN     88467           NaN
# 4257             NaN           NaN     88476           NaN
# 4258         Chicago         60623     88470          28.0
# 12057         Skokie         60077     80661           NaN
#
#       Chicago Community Area COVID Related Updated_Date_of_Death  \
# 3552      EAST GARFIELD PARK         False   2023-07-25 00:00:00
# 4254                     NaN         False   2023-05-03 23:36:00
# 4257                     NaN         False   2023-05-15 06:29:00
# 4258          SOUTH LAWNDALE         False   2022-03-06 19:20:00
# 12057                    NaN         False   2023-12-01 07:52:00
#
#        Year_of_Death
# 3552          2023.0
# 4254          2023.0
# 4257          2023.0
# 4258          2022.0
# 12057         2023.0

# %%
len(df_me)
# 53086 deaths between 2019 and 2023
# Out:
# 53086

# %%
# create columns for deaths related to drugs 
fent_names = "FENTANYL| 4-ANILINO-N-PHENETHYLPIPERIDINE | 4-ANPP | Acetyl-alphamethyl-fentanyl | Alfentanil | Alpha-methylfentanyl | 4ANPP | 4FIBF | Alpha-methylthiofentanyl | Beta-hydroxyfentanyl | Beta-hydroxy-3 methylfentanyl | 3-methylfentanyl | 3-methylthio-fentanyl | Para-fluoro-fentanyl | Remifentanil | Sufentanil | Thiofentanyl | Carfentanil | 2-furanoylfentanyl | Furanylfentanyl | 4-anilino-N-phenethylpiperidine | 4-Fluorofentanyl | ACETYLFENTANYL | ACRYLFENTANYL | Butyrfentanyl | Lofentanil | Valerylfentanyl | Isobutyrylfentanyl"
df_me['contanins_fentanyl'] = df_me['Primary Cause'].str.contains(fent_names, case=False, na=False)

# %%
df_me['contains_cocaine'] = df_me['Primary Cause'].str.contains("cocaine|Benzoylmethylecgonine", case=False, na=False)
df_me["contains_heroin"] =df_me['Primary Cause'].str.contains('HEROIN', case=False, na=False)

# %%
df_me["Incident Zip Code"] = df_me["Incident Zip Code"].astype(str).str.extract(r"(\d{5})")
df_me["Incident Zip Code"] = df_me["Incident Zip Code"].str.zfill(5)
df_me.head()
# Out:
#         Case Number        Date of Incident           Date of Death   Age  \
# 3552   ME2025-02283  04/21/2023 02:08:00 PM  07/25/2023 12:00:00 AM  42.0
# 4254   ME2025-01581  03/10/2025 12:00:00 AM  05/03/2023 11:36:00 PM  84.0
# 4257   ME2025-01578                     NaN  05/15/2023 06:29:00 AM  76.0
# 4258   ME2025-01577  03/06/2022 08:11:00 PM  03/06/2022 07:20:00 PM  71.0
# 12057  ME2024-00980  11/30/2023 02:23:00 PM  12/01/2023 07:52:00 AM  87.0
#
#        Gender   Race  Latino Manner of Death  \
# 3552     Male  Black   False        ACCIDENT
# 4254     Male  Black   False         NATURAL
# 4257     Male  White   False         NATURAL
# 4258     Male  White    True         NATURAL
# 12057  Female  Asian   False         NATURAL
#
#                                            Primary Cause  \
# 3552                           COMPLICATIONS OF DROWNING
# 4254           MALIGNANT NEOPLASM OF THE URINARY BLADDER
# 4257   HYPERTENSIVE ARTERIOSCLEROTIC CARDIOVASCULAR D...
# 4258                                  CHRONIC ETHANOLISM
# 12057                           SEPSIS. BRONCHOPNEUMONIA
#
#                                     Primary Cause Line A Primary Cause Line B  \
# 3552                           COMPLICATIONS OF DROWNING                  NaN
# 4254           MALIGNANT NEOPLASM OF THE URINARY BLADDER                  NaN
# 4257   HYPERTENSIVE ARTERIOSCLEROTIC CARDIOVASCULAR D...                  NaN
# 4258                                  CHRONIC ETHANOLISM                  NaN
# 12057                                             SEPSIS     BRONCHOPNEUMONIA
#
#       Primary Cause Line C                                    Secondary Cause  \
# 3552                   NaN  HYPERTENSIVE CARDIOVASCULAR DISEASE, CHRONIC S...
# 4254                   NaN                                                NaN
# 4257                   NaN                                  DIABETES MELLITUS
# 4258                   NaN                                  DIABETES MELLITUS
# 12057                  NaN  HYPERTENSIVE AND ATHEROSCLEROTIC CARDIOVASCULA...
#
#       Gun Related Opioid Related  Cold Related  Heat Related  \
# 3552        False          False         False         False
# 4254        False          False         False         False
# 4257        False          False         False         False
# 4258        False          False         False         False
# 12057       False          False         False         False
#
#        Commissioner District           Incident Address    Incident City  \
# 3552                     1.0  100 N Central Park Avenue          CHICAGO
# 4254                     5.0            230 E. 11th St.  CHICAGO HEIGHTS
# 4257                     NaN                        NaN          UNKNOWN
# 4258                     7.0        2551 W. CERMAK ROAD          CHICAGO
# 12057                    NaN      8110 Lincoln Ave. #2C          CHICAGO
#
#       Incident Zip Code  longitude   latitude                  location  \
# 3552              60624 -87.716075  41.882688  (41.882688, -87.7160745)
# 4254              60411 -87.625580  41.511357  (41.511357, -87.6255795)
# 4257                NaN        NaN        NaN                       NaN
# 4258              60608 -87.690001  41.850558  (41.850558, -87.6900015)
# 12057             60646        NaN        NaN                       NaN
#
#       Residence City Residence Zip  OBJECTID  Chicago Ward  \
# 3552    Elmwood Park         60707     89165          28.0
# 4254             NaN           NaN     88467           NaN
# 4257             NaN           NaN     88476           NaN
# 4258         Chicago         60623     88470          28.0
# 12057         Skokie         60077     80661           NaN
#
#       Chicago Community Area COVID Related Updated_Date_of_Death  \
# 3552      EAST GARFIELD PARK         False   2023-07-25 00:00:00
# 4254                     NaN         False   2023-05-03 23:36:00
# 4257                     NaN         False   2023-05-15 06:29:00
# 4258          SOUTH LAWNDALE         False   2022-03-06 19:20:00
# 12057                    NaN         False   2023-12-01 07:52:00
#
#        Year_of_Death  contanins_fentanyl  contains_cocaine  contains_heroin
# 3552          2023.0               False             False            False
# 4254          2023.0               False             False            False
# 4257          2023.0               False             False            False
# 4258          2022.0               False             False            False
# 12057         2023.0               False             False            False

# %%
df_me.head()
# Out:
#         Case Number        Date of Incident           Date of Death   Age  \
# 3552   ME2025-02283  04/21/2023 02:08:00 PM  07/25/2023 12:00:00 AM  42.0
# 4254   ME2025-01581  03/10/2025 12:00:00 AM  05/03/2023 11:36:00 PM  84.0
# 4257   ME2025-01578                     NaN  05/15/2023 06:29:00 AM  76.0
# 4258   ME2025-01577  03/06/2022 08:11:00 PM  03/06/2022 07:20:00 PM  71.0
# 12057  ME2024-00980  11/30/2023 02:23:00 PM  12/01/2023 07:52:00 AM  87.0
#
#        Gender   Race  Latino Manner of Death  \
# 3552     Male  Black   False        ACCIDENT
# 4254     Male  Black   False         NATURAL
# 4257     Male  White   False         NATURAL
# 4258     Male  White    True         NATURAL
# 12057  Female  Asian   False         NATURAL
#
#                                            Primary Cause  \
# 3552                           COMPLICATIONS OF DROWNING
# 4254           MALIGNANT NEOPLASM OF THE URINARY BLADDER
# 4257   HYPERTENSIVE ARTERIOSCLEROTIC CARDIOVASCULAR D...
# 4258                                  CHRONIC ETHANOLISM
# 12057                           SEPSIS. BRONCHOPNEUMONIA
#
#                                     Primary Cause Line A Primary Cause Line B  \
# 3552                           COMPLICATIONS OF DROWNING                  NaN
# 4254           MALIGNANT NEOPLASM OF THE URINARY BLADDER                  NaN
# 4257   HYPERTENSIVE ARTERIOSCLEROTIC CARDIOVASCULAR D...                  NaN
# 4258                                  CHRONIC ETHANOLISM                  NaN
# 12057                                             SEPSIS     BRONCHOPNEUMONIA
#
#       Primary Cause Line C                                    Secondary Cause  \
# 3552                   NaN  HYPERTENSIVE CARDIOVASCULAR DISEASE, CHRONIC S...
# 4254                   NaN                                                NaN
# 4257                   NaN                                  DIABETES MELLITUS
# 4258                   NaN                                  DIABETES MELLITUS
# 12057                  NaN  HYPERTENSIVE AND ATHEROSCLEROTIC CARDIOVASCULA...
#
#       Gun Related Opioid Related  Cold Related  Heat Related  \
# 3552        False          False         False         False
# 4254        False          False         False         False
# 4257        False          False         False         False
# 4258        False          False         False         False
# 12057       False          False         False         False
#
#        Commissioner District           Incident Address    Incident City  \
# 3552                     1.0  100 N Central Park Avenue          CHICAGO
# 4254                     5.0            230 E. 11th St.  CHICAGO HEIGHTS
# 4257                     NaN                        NaN          UNKNOWN
# 4258                     7.0        2551 W. CERMAK ROAD          CHICAGO
# 12057                    NaN      8110 Lincoln Ave. #2C          CHICAGO
#
#       Incident Zip Code  longitude   latitude                  location  \
# 3552              60624 -87.716075  41.882688  (41.882688, -87.7160745)
# 4254              60411 -87.625580  41.511357  (41.511357, -87.6255795)
# 4257                NaN        NaN        NaN                       NaN
# 4258              60608 -87.690001  41.850558  (41.850558, -87.6900015)
# 12057             60646        NaN        NaN                       NaN
#
#       Residence City Residence Zip  OBJECTID  Chicago Ward  \
# 3552    Elmwood Park         60707     89165          28.0
# 4254             NaN           NaN     88467           NaN
# 4257             NaN           NaN     88476           NaN
# 4258         Chicago         60623     88470          28.0
# 12057         Skokie         60077     80661           NaN
#
#       Chicago Community Area COVID Related Updated_Date_of_Death  \
# 3552      EAST GARFIELD PARK         False   2023-07-25 00:00:00
# 4254                     NaN         False   2023-05-03 23:36:00
# 4257                     NaN         False   2023-05-15 06:29:00
# 4258          SOUTH LAWNDALE         False   2022-03-06 19:20:00
# 12057                    NaN         False   2023-12-01 07:52:00
#
#        Year_of_Death  contanins_fentanyl  contains_cocaine  contains_heroin
# 3552          2023.0               False             False            False
# 4254          2023.0               False             False            False
# 4257          2023.0               False             False            False
# 4258          2022.0               False             False            False
# 12057         2023.0               False             False            False

# %%
df_me.isna().sum()
# 1295 missing zip code
# Out:
# Case Number                   0
# Date of Incident           1693
# Date of Death                 0
# Age                         170
# Gender                      116
# Race                        231
# Latino                        0
# Manner of Death             252
# Primary Cause                14
# Primary Cause Line A         14
# Primary Cause Line B      33920
# Primary Cause Line C      50234
# Secondary Cause           29868
# Gun Related                 254
# Opioid Related              254
# Cold Related                  0
# Heat Related                  0
# Commissioner District      6914
# Incident Address            822
# Incident City               958
# Incident Zip Code          1295
# longitude                  6909
# latitude                   6909
# location                   6909
# Residence City             1169
# Residence Zip              1151
# OBJECTID                      0
# Chicago Ward              24105
# Chicago Community Area    24105
# COVID Related                 2
# Updated_Date_of_Death         0
# Year_of_Death                 0
# contanins_fentanyl            0
# contains_cocaine              0
# contains_heroin               0
# dtype: int64

# %%
df_me = df_me.dropna(subset=["Incident Zip Code"])
len(df_me)
# Out:
# 51791

# %%
df_me.isna().sum()
# Out:
# Case Number                   0
# Date of Incident           1266
# Date of Death                 0
# Age                         160
# Gender                      106
# Race                        216
# Latino                        0
# Manner of Death             241
# Primary Cause                14
# Primary Cause Line A         14
# Primary Cause Line B      33387
# Primary Cause Line C      49101
# Secondary Cause           29409
# Gun Related                 243
# Opioid Related              243
# Cold Related                  0
# Heat Related                  0
# Commissioner District      5656
# Incident Address            155
# Incident City                78
# Incident Zip Code             0
# longitude                  5651
# latitude                   5651
# location                   5651
# Residence City             1062
# Residence Zip              1051
# OBJECTID                      0
# Chicago Ward              22836
# Chicago Community Area    22836
# COVID Related                 2
# Updated_Date_of_Death         0
# Year_of_Death                 0
# contanins_fentanyl            0
# contains_cocaine              0
# contains_heroin               0
# dtype: int64

# %%
# AFTER CLEANING, save ME data to this!!!


# df_me = pd.read_csv('data/raw/cook_county_medical_examiner.csv')
# df_census = pd.read_csv('data/raw/census_tract_data.csv')

# # Save processed copy and compute checksum
# df_me.to_csv('data/processed/me_clean.csv', index=False)
# with open('data/processed/me_clean.csv', 'rb') as f:
#     checksum = hashlib.sha256(f.read()).hexdigest()
# print("Checksum:", checksum)
